# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import warnings
warnings.filterwarnings("ignore")

# %%
olympics = pd.read_csv("../input/120-years-of-olympic-history-athletes-and-results/athlete_events.csv")
o_region = pd.read_csv("../input/120-years-of-olympic-history-athletes-and-results/noc_regions.csv")
olympics
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal
# 0          Basketball               Basketball Men's Basketball   NaN
# 1                Judo              Judo Men's Extra-Lightweight   NaN
# 2            Football                   Football Men's Football   NaN
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres   NaN
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles   NaN
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual   NaN
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team   NaN
# 271114      Bobsleigh                      Bobsleigh Men's Four   NaN
# 271115      Bobsleigh                      Bobsleigh Men's Four   NaN
#
# [271116 rows x 15 columns]

# %% [markdown]
# # Data Exploration

# %%
def missing_values_analysis(df):
    na_columns_ = [col for col in df.columns if df[col].isnull().sum() > 0]
    n_miss = df[na_columns_].isnull().sum().sort_values(ascending=True)
    ratio_ = (df[na_columns_].isnull().sum() / df.shape[0] * 100).sort_values(ascending=True)
    missing_df = pd.concat([n_miss, np.round(ratio_, 2)], axis=1, keys=['Total Missing Values', 'Ratio'])
    missing_df = pd.DataFrame(missing_df)
    return missing_df

def check_df(df, head=5):
    print("--------------------- Shape --------------------")
    print(df.shape)
    print("-------------------- Types ---------------------")
    print(df.dtypes)
    print("----------------- NaN Analysis -----------------")
    print(missing_values_analysis(df))
    print("--------------------- Head ---------------------")
    print(df.head())

check_df(olympics)
# Out:
# --------------------- Shape --------------------
# (271116, 15)
# -------------------- Types ---------------------
# ID          int64
# Name       object
# Sex        object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year        int64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# dtype: object
# ----------------- NaN Analysis -----------------
#         Total Missing Values  Ratio
# Age                     9474   3.49
# Height                 60171  22.19
# Weight                 62875  23.19
# Medal                 231333  85.33
# --------------------- Head ---------------------
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %% [markdown]
# # Exploratory Data Analysis

# %%
sns.pairplot(olympics)

# %% [markdown]
# # Age

# %%
olympics.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
plt.figure(figsize=(18,8))
sns.set(style='whitegrid',)
sns.distplot(olympics["Age"], color="purple")
plt.xlabel("Age of the players",fontsize=14, weight="semibold")
plt.ylabel("Density",fontsize=15, weight="semibold")
plt.show()

# %%
sns.set(style='ticks',)
sns.displot(olympics, x="Age", hue="Sex",
            alpha=0.5,
            binwidth=2,
            height=8, aspect=2)
plt.xlabel("Age of the players",fontsize=14, weight="semibold")
plt.ylabel("Density",fontsize=15, weight="semibold")
# Out:
# Text(-9.194835069444443, 0.5, 'Density')

# %%
plt.figure(figsize=(24,20))
sns.set(style="whitegrid",)
sns.boxplot(data=olympics, x="Age", y="Height")
plt.xticks(rotation=45, weight="semibold")
plt.yticks(weight="semibold", fontsize=13)
plt.xlabel("Age of the players",fontsize=14, weight="semibold")
plt.ylabel("Height in centimeters",fontsize=15, weight="semibold")

plt.show()

# %% [markdown]
# # Medals

# %%
olympics.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
medal_players = olympics[olympics["Medal"].notna()]
medal_players.head()
# Out:
#     ID                      Name Sex   Age  Height  Weight            Team  \
# 3    4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 37  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 38  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0         Finland
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
#
#     NOC        Games  Year  Season       City       Sport  \
# 3   DEN  1900 Summer  1900  Summer      Paris  Tug-Of-War
# 37  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 38  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 40  FIN  2014 Winter  2014  Winter      Sochi  Ice Hockey
# 41  FIN  1948 Summer  1948  Summer     London  Gymnastics
#
#                                      Event   Medal
# 3              Tug-Of-War Men's Tug-Of-War    Gold
# 37  Swimming Men's 200 metres Breaststroke  Bronze
# 38  Swimming Men's 400 metres Breaststroke  Bronze
# 40             Ice Hockey Men's Ice Hockey  Bronze
# 41  Gymnastics Men's Individual All-Around  Bronze

# %%
fig = px.histogram(medal_players, x="Medal", color="Sex",
             barmode='group', title='Total medals with respect to gender', 
             color_discrete_map={"M": "RebeccaPurple", "F": "MediumPurple"},
             template='simple_white', opacity=1
            )
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="f26b32b9-1c49-4a3a-a5cb-a180744e1c45" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f26b32b9-1c49-4a3a-a5cb-a180744e1c45")) {                    Plotly.newPlot(                        "f26b32b9-1c49-4a3a-a5cb-a180744e1c45",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sex=M\u003cbr\u003eMedal=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M","marker":{"color":"RebeccaPurple","opacity":1,"pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":true,"x":["Gold","Bronze","Bronze","Bronze","Bronze","Gold","Gold","Gold","Bronze","Gold","Bronze","Silver","Bronze","Silver","Gold","Gold","Gold","Silver","Silver","Silver","Bronze","Gold","Gold","Gold","Bronze","Bronze","Gold","Gold","Gold","Silver","Gold","Gold","Silver","Gold","Bronze","Gold","Silver","Bronze","Bronze","Gold","Gold","Gold","Gold","Gold","Silver","Gold","Gold","Silver","Bronze","Bronze","Bronze","Bronze","Gold","Silver","Gold","Gold","Silver","Gold","Gold","Silver","Gold","Gold","Bronze","Silver","Silver","Gold","Silver","Gold","Gold","Gold","Gold","Bronze","Silver","Gold","Gold","Gold","Bronze","Silver","Silver","Silver","Bronze","Silver","Bronze","Bronze","Silver","Bronze","Gold","Silver","Bronze","Silver","Gold","Silver","Gold","Bronze","Silver","Bronze","Bronze","Gold","Gold","Gold","Gold","Bronze","Gold","Gold","Bronze","Silver","Bronze","Silver","Bronze","Silver","Bronze","Bronze","Gold","Gold","Gold","Silver","Silver","Silver","Gold","Bronze","Gold","Silver","Silver","Gold","Bronze","Bronze","Bronze","Gold","Silver","Gold","Bronze","Gold","Silver","Silver","Bronze","Silver","Gold","Silver","Silver","Gold","Silver","Gold","Gold","Silver","Bronze","Bronze","Silver","Silver","Silver","Silver","Silver","Bronze","Gold","Silver","Bronze","Gold","Gold","Silver","Silver","Silver","Bronze","Gold","Gold","Gold","Silver","Bronze","Gold","Gold","Silver","Gold","Bronze","Bronze","Gold","Gold","Silver","Silver","Bronze","Bronze","Silver","Bronze","Bronze","Silver","Gold","Bronze","Bronze","Silver","Bronze","Gold","Gold","Silver","Silver","Gold","Bronze","Silver","Silver","Bronze","Gold","Gold","Bronze","Bronze","Silver","Gold","Bronze","Bronze","Silver","Bronze","Silver","Silver","Gold","Bronze","Bronze","Silver","Bronze","Gold","Gold","Bronze","Bronze","Gold","Gold","Gold","Bronze","Gold","Gold","Gold","Silver","Bronze","Bronze","Silver","Silver","Silver","Gold","Silver","Silver","Bronze","Silver","Silver","Bronze","Silver","Silver","Gold","Gold","Bronze","Bronze","Bronze","Silver","Gold","Gold","Gold","Gold","Gold","Gold","Bronze","Silver","Silver","Bronze","Gold","Gold","Gold","Bronze","Gold","Gold","Silver","Silver","Bronze","Silver","Bronze","Bronze","Silver","Bronze","Gold","Bronze","Bronze","Silver","Silver","Gold","Silver","Gold","Gold","Bronze","Gold","Silver","Silver","Bronze","Gold","Gold","Gold","Gold","Gold","Silver","Bronze","Silver","Bronze","Bronze","Gold","Bronze","Silver","Bronze","Bronze","Bronze","Bronze","Gold","Bronze","Bronze","Gold","Gold","Bronze","Bronze","Silver","Silver","Silver","Silver","Gold","Silver","Bronze","Gold","Bronze","Silver","Silver","Bronze","Gold","Silver","Bronze","Bronze","Silver","Bronze","Silver","Gold","Silver","Bronze","Bronze","Gold","Bronze","Bronze","Gold","Bronze","Gold","Gold","Silver","Bronze","Bronze","Silver","Gold","Silver","Silver","Silver","Gold","Silver","Silver","Gold","Gold","Bronze","Gold","Silver","Bronze","Gold","Gold","Bronze","Bronze","Gold","Gold","Gold","Bronze","Gold","Bronze","Silver","Silver","Silver","Silver","Bronze","Gold","Bronze","Silver","Silver","Silver","Bronze","Silver","Bronze","Silver","Gold","Gold","Bronze","Gold"," ...

# %%
px.histogram(medal_players, x="Team", color="Medal",
      barmode="group")
# Out:
# <div>                            <div id="c1b95840-3e82-4d97-8c71-6f0160849c7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c1b95840-3e82-4d97-8c71-6f0160849c7b")) {                    Plotly.newPlot(                        "c1b95840-3e82-4d97-8c71-6f0160849c7b",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Medal=Gold\u003cbr\u003eTeam=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gold","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Gold","offsetgroup":"Gold","orientation":"v","showlegend":true,"x":["Denmark\u002fSweden","Finland","Finland","Finland","Norway","Norway","Norway","Norway","Norway","Norway","Taifun","France","Belarus","France","France","Cameroon","Spain","Spain","France","Italy","Italy","Italy","Italy","Italy","Italy","Italy","United States","Pakistan","Soviet Union","Uzbekistan","Azerbaijan","United States","Unified Team","Japan","Canada","Spain","Vesper Boat Club","Vesper Boat Club","Ethiopia","United States","Bulgaria","United States","Hungary","Great Britain","Norway","Soviet Union","France","France","Jordan","Soviet Union","France","Sweden","New Zealand","United States","Switzerland-1","Switzerland-1","Argentina","United States","Canada","France","United States","Great Britain","Great Britain","United States","New Zealand","New Zealand","Germany","Germany","Brazil","France-1","United States","United States","Sweden","Sweden","Sweden","Great Britain","Great Britain","United States","United States","United States","United States","United States","Romania","United States","Netherlands","Netherlands","France","France","Canada","Canada","Canada","Hungary","Italy","Large boat, Central Naval Prep School \"Poros\"-1","Netherlands","Argentina","Cuba","Great Britain","United States","Indonesia-1","Sweden","United States","United States","Pakistan","Pakistan","Pakistan","Pakistan","Pakistan","Pakistan","East Germany","United States","Japan","Japan","Great Britain","Great Britain","Great Britain","Great Britain","United States","Great Britain","Australia","Union des Socits Franais de Sports Athletiques","Ukraine","Cuba","Cuba","Nigeria","Turkey","Sweden","Bissbi","United States","Turkey","Soviet Union","Russia","Russia","Pakistan","Pakistan","Uganda","Soviet Union","Soviet Union","United States","Soviet Union","Individual Olympic Athletes","Pakistan","United Arab Emirates","Spain","Pakistan","Finland","Italy","Union des Socits Franais de Sports Athletiques","Denmark","Russia","Switzerland","Sweden","United States","Cuba","United States","New Zealand","Lithuania","Lithuania","Soviet Union","Soviet Union","Soviet Union","Soviet Union","Armenia","Soviet Union","Soviet Union","Serbia","France","Spain","United States","Sweden","Sweden","Pakistan","India","India","France","France","Russia","Soviet Union","Russia","Greece","Brazil-1","Russia","Belgium","Belgium","United States","Austria","Australia","United States","India","India","India","United States","Heira II","Nykjbings paa Falster","Great Britain","Italy","United States","Italy","Soviet Union","Cameroon","Norway","Norway","Norway","Norway","Norway","Norway","Switzerland-1","Great Britain","Spain","Soviet Union","Soviet Union","Soviet Union","Romania","Romania","Romania","Germany","France","Brazil","Spain","Italy","United States","Hungary","East Germany-1","United States","United States","Switzerland","Switzerland","Switzerland","Switzerland","Nigeria","Great Britain","Soviet Union","East Germany","Norway","Nigeria","Canada","South Korea","South Korea","North Korea","South Korea","South Korea","South Korea","South Korea","Russia","Russia","Russia","Canada-1","Yugoslavia","Poland","France","Sweden","Denmark","Norway","Denmark","Denmark","Denmark"," ...

# %%
#calculating total medals for each country
medal_players["Medal_Count"] = medal_players.groupby("Medal")["Medal"].transform('count')
df = medal_players.query("Medal_Count > 250")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39783 entries, 3 to 271103
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           39783 non-null  int64
#  1   Name         39783 non-null  object
#  2   Sex          39783 non-null  object
#  3   Age          39051 non-null  float64
#  4   Height       31072 non-null  float64
#  5   Weight       30456 non-null  float64
#  6   Team         39783 non-null  object
#  7   NOC          39783 non-null  object
#  8   Games        39783 non-null  object
#  9   Year         39783 non-null  int64
#  10  Season       39783 non-null  object
#  11  City         39783 non-null  object
#  12  Sport        39783 non-null  object
#  13  Event        39783 non-null  object
#  14  Medal        39783 non-null  object
#  15  Medal_Count  39783 non-null  int64
# dtypes: float64(3), int64(3), object(10)
# memory usage: 5.2+ MB

# %%
#px.histogram(df, x="Team", color="Medal", barmode="group")
#df.info()
